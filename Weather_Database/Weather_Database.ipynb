# %%
#Import Dependencies

from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a list of 2000 random latitude and longitude 

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list of coordinates 

coordinates = list(lat_lngs)
print (coordinates)
# Out:
# [(65.1249027992834, -161.04086802741068), (26.960293270233862, 113.69474508887248), (-61.240673407266506, -96.00387888897804), (45.710061665401895, -3.442558938292848), (-81.90615534800213, 61.027751180940726), (8.86190185852557, -70.3547982841638), (69.34701643087826, 111.57262889358697), (-19.375396356196376, -177.2613169512831), (-44.55336050355908, 146.41757742491393), (-73.49416103653573, 138.65906150391135), (35.9452119622715, 178.63241296144508), (36.34656927117575, -137.61434641290106), (-46.840965990251895, -102.73280539075913), (-69.78233258338594, -103.59061126794752), (87.52664118509207, -167.13240861497832), (-84.3724886538859, 157.32750240214676), (-19.277161566960203, 123.96441734359729), (-77.10647221139679, 79.40167967928744), (-46.340721333341826, 13.396105275129997), (-10.86550914508463, -7.150323599656957), (-85.13900246723526, 81.64972280923371), (50.35898820012633, -72.13772751605245), (-3.562987110291658, 28.019564622609664), (-31.90965468914804, -124.58705147674902), (-27.434413969103026, 165.54652063667027), (52.35478098582888, -84.88713008852079), (-61.52272710769184, 83.61406799327801), (10.29601451887656, -63.30221039690326), (-48.05840085850594, -63.70489393644486), (85.01274889286071, 93.1139376360797), (-65.0181301024989, -69.2602886528873), (57.60071207463051, -149.08705891188362), (-32.00153012920622, -58.618882355030806), (17.388499248308918, 148.00875078638495), (11.709957779423505, 127.83145706080319), (73.11695170469258, -138.6485848543208), (-15.808656656637467, -75.14580873162052), (-30.18160749069201, -77.1897044383818), (-43.93278717948927, -167.58407178523947), (-3.379056313643005, -149.31697385184071), (83.00443101135704, 13.323424176534928), (21.26499058393115, -49.150517407990094), (59.15233584086951, 15.27287953221466), (-5.3932679662514005, -94.29892999744536), (76.37819142711581, 165.96067509750048), (-52.56906645713185, -159.14524642981453), (20.744596665824716, 162.79428566277517), (5.036490021627529, 144.49122541705998), (75.51260394103016, -42.80190457797886), (34.11262966270711, 0.34482610217111187), (25.63606439268503, -80.18959247021805), (-78.49832584288521, -24.0448133586506), (69.24958152699836, -133.0937657292369), (6.982879239806294, -31.47829543392794), (-69.29426521920286, 45.13294837373897), (58.50188722510171, -143.8003160187049), (-59.200396227776594, 155.87180720571916), (-66.44581034943533, 129.95089991066635), (-74.70500092315633, 73.62818008104517), (-75.30683910563266, 148.15569964390568), (10.115173362727347, -58.00891017917543), (60.2787889239554, -9.693759751520332), (-29.859222028629574, 35.714942707068474), (66.75132721128765, -126.73755754043736), (72.9991612616844, 11.532508429794888), (-56.65128376457817, -4.026744919748495), (26.722752473264464, 3.0051360142076646), (80.43034185324919, -61.660305365648725), (-15.321705911218118, -42.44388769154523), (16.900276925120494, -44.86911706929081), (-52.671121637636695, -139.20851496847337), (64.90379780148825, 51.56995868639487), (-44.979778791209846, 41.14141603456221), (-24.13031883645499, -122.34810610394791), (51.118513156608316, -63.34911097172835), (1.4059333883664635, -57.032117136932285), (-56.70423024991643, -173.43012578100357), (-14.617906065930356, -70.19268770583373), (-55.26421981847512, -28.378703783022672), (-34.96793079537652, 19.90115956200097), (52.68115126495016, -113.89341048794564), (51.36035567467894, -164.78869307774838), (75.36768489385386, 89.57599175094293), (-60.23884083238664, -122.45975438884713), (-36.04885125055945, 173.76675659214942), (-21.039660708331027, -89.7880521090843), (56.18640575048505, 73.70744678092896), (-7.977038903804839, 47.32079781445182), (-81.89991518455095, -117.89215259290403), (44.70211743946379, -11.930730552185537), (-85.69631385951251, 94.77899964001404), (35.625900166224596, 111.74813075074752), (-51.503762085861396, 163.87513336987462), (32.98477149554269, 69.70501083090659), (-19.214655503614765, -115.75026194899152), (49.15238736594179, -165.648 ...

# %%
# Get the nearest city using the citipy module

cities = []


for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    
    if city not in cities:
        cities.append(city)
        
        
# Print the city count
len(cities)
# Out:
# 761

# %%
#  API call to OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")


record_count = 1
set_count = 1

# Loop through all cities
for i, city in enumerate(cities):

    # Group cities in set of fifty
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    
    
    
    city_url = url + "&q=" + city.replace(" ","+")
    
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
    
    
    
# Run an API request 
    try:
        
        city_weather = requests.get(city_url).json()
    
    
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is found skit the city
    except:
        print("City not found. Skipping...")
        pass

    
    
    
print("-----------------------")
print("Data Retrieval Complete")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bethel
# Processing Record 2 of Set 1 | pingxiang
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | la baule-escoublac
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | barinitas
# Processing Record 7 of Set 1 | udachnyy
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | nikolskoye
# Processing Record 12 of Set 1 | fortuna
# Processing Record 13 of Set 1 | castro
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | broome
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | dolbeau
# City not found. Skipping...
# Processing Record 21 of Set 1 | uvira
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | vao
# Processing Record 24 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 1 | carupano
# Processing Record 26 of Set 1 | comodoro rivadavia
# Processing Record 27 of Set 1 | khatanga
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | homer
# Processing Record 30 of Set 1 | concepcion del uruguay
# Processing Record 31 of Set 1 | airai
# Processing Record 32 of Set 1 | sulangan
# Processing Record 33 of Set 1 | aklavik
# Processing Record 34 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 1 | coquimbo
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 1 | saint-francois
# Processing Record 39 of Set 1 | kumla
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | pevek
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | butaritari
# Processing Record 44 of Set 1 | lorengau
# Processing Record 45 of Set 1 | ilulissat
# Processing Record 46 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 47 of Set 1 | key biscayne
# Processing Record 48 of Set 1 | tuktoyaktuk
# Processing Record 49 of Set 1 | sao filipe
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | palmer
# Processing Record 2 of Set 2 | tuatapere
# Processing Record 3 of Set 2 | saint-philippe
# Processing Record 4 of Set 2 | mabaruma
# Processing Record 5 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 2 | richards bay
# Processing Record 7 of Set 2 | norman wells
# Processing Record 8 of Set 2 | gravdal
# Processing Record 9 of Set 2 | cape town
# Processing Record 10 of Set 2 | adrar
# Processing Record 11 of Set 2 | narsaq
# Processing Record 12 of Set 2 | rio pardo de minas
# Processing Record 13 of Set 2 | sinnamary
# Processing Record 14 of Set 2 | ust-tsilma
# Processing Record 15 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 2 | havre-saint-pierre
# Processing Record 17 of Set 2 | bonfim
# Processing Record 18 of Set 2 | azangaro
# Processing Record 19 of Set 2 | chuy
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | lacombe
# Processing Record 22 of Set 2 | talnakh
# Processing Record 23 of Set 2 | dargaville
# Processing Record 24 of Set 2 | pisco
# Processing Record 25 of Set 2 | kolosovka
# Processing Record 26 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 27 of Set 2 | muros
# Processing Record 28 of Set 2 | albany
# Processing Record 29 of Set 2 | houma
# Processing Record 30 of Set 2 | miram shah
# Processing Record 31 of Set 2 | kahului
# Processing Record 32 of Set 2 | husavik
# Processing Record 33 of Set 2 | cherskiy
# Processing Record 34 of Set 2 | thompson
# Processing Record 35 of Set 2 | golden
# Processing Record 36 of Set 2 | port elizabeth
# Processing Record 37 of Set 2 | klaksvik
# Processing Record 38 of Set 2 | port-gentil
# Processing Record 39 of Set 2 | kavieng
# Processing Record 40 of Set 2 | kaitangata
# Processing Record 41 of Set 2 | isangel
# Processing Record 42 of Set 2 | qaanaaq
# Processing Record 43 of Set 2 | kachug
# Processing Record 44 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 2 | talcahuano
# Processing Record 46 of Set 2 | chernyshevskiy
# Processing Record 47 of Set 2 | tiksi
# Processing Record 48 of Set 2 | san patricio
# Processing Record 49 of Set 2 | ishigaki
# Processing Record 50 of Set 2 | carnarvon
# Processing Record 1 of Set 3 | iisaku
# Processing Record 2 of Set 3 | skiathos
# Processing Record 3 of Set 3 | bengkulu
# Processing Record 4 of Set 3 | labuan
# Processing Record 5 of Set 3 | kodiak
# Processing Record 6 of Set 3 | ust-nera
# Processing Record 7 of Set 3 | zomin
# Processing Record 8 of Set 3 | college
# Processing Record 9 of Set 3 | dikson
# Processing Record 10 of Set 3 | dudinka
# Processing Record 11 of Set 3 | baboua
# City not found. Skipping...
# Processing Record 12 of Set 3 | bubaque
# Processing Record 13 of Set 3 | yellowknife
# Processing Record 14 of Set 3 | myitkyina
# Processing Record 15 of Set 3 | hasaki
# Processing Record 16 of Set 3 | hilo
# Processing Record 17 of Set 3 | margate
# Processing Record 18 of Set 3 | anadyr
# Processing Record 19 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 21 of Set 3 | mari-turek
# Processing Record 22 of Set 3 | vostok
# Processing Record 23 of Set 3 | calvinia
# Processing Record 24 of Set 3 | khatima
# Processing Record 25 of Set 3 | pulivendla
# Processing Record 26 of Set 3 | avarua
# Processing Record 27 of Set 3 | santa rosa
# Processing Record 28 of Set 3 | visnes
# Processing Record 29 of Set 3 | bathsheba
# Processing Record 30 of Set 3 | torbay
# Processing Record 31 of Set 3 | georgetown
# Processing Record 32 of Set 3 | piacabucu
# Processing Record 33 of Set 3 | kapaa
# Processing Record 34 of Set 3 | dunedin
# Processing Record 35 of Set 3 | tasiilaq
# Processing Record 36 of Set 3 | port hedland
# Processing Record 37 of Set 3 | atbasar
# Processing Record 38 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 3 | chinnammanur
# City not found. Skipping...
# Processing Record 40 of Set 3 | nisia floresta
# Processing Record 41 of Set 3 | lebu
# Processing Record 42 of Set 3 | tete
# Processing Record 43 of Set 3 | nome
# Processing Record 44 of Set 3 | barra dos coqueiros
# Processing Record 45 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 3 | la paz
# Processing Record 47 of Set 3 | faanui
# Processing Record 48 of Set 3 | acapulco
# Processing Record 49 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 3 | ancud
# Processing Record 1 of Set 4 | port lincoln
# Processing Record 2 of Set 4 | saint anthony
# Processing Record 3 of Set 4 | melito di porto salvo
# Processing Record 4 of Set 4 | dingle
# Processing Record 5 of Set 4 | togur
# Processing Record 6 of Set 4 | guerrero negro
# Processing Record 7 of Set 4 | port hardy
# Processing Record 8 of Set 4 | kavaratti
# Processing Record 9 of Set 4 | lagoa
# Processing Record 10 of Set 4 | kulhudhuffushi
# Processing Record 11 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 12 of Set 4 | nantucket
# Processing Record 13 of Set 4 | cabedelo
# Processing Record 14 of Set 4 | kalmunai
# Processing Record 15 of Set 4 | victoria
# Processing Record 16 of Set 4 | kuytun
# Processing Record 17 of Set 4 | yulara
# Processing Record 18 of Set 4 | maltahohe
# Processing Record 19 of Set 4 | saint george
# Processing Record 20 of Set 4 | san francisco
# Processing Record 21 of Set 4 | kamaishi
# Processing Record 22 of Set 4 | calahorra
# Processing Record 23 of Set 4 | tura
# Processing Record 24 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 4 | chama
# Processing Record 26 of Set 4 | east london
# Processing Record 27 of Set 4 | malini
# Processing Record 28 of Set 4 | vitim
# Processing Record 29 of Set 4 | lavrentiya
# Processing Record 30 of Set 4 | kamyaran
# Processing Record 31 of Set 4 | vila velha
# Processing Record 32 of Set 4 | forio
# Processing Record 33 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 4 | souillac
# Processing Record 35 of Set 4 | ulagan
# Processing Record 36 of Set 4 | mar del plata
# Processing Record 37 of Set 4 | bambous virieux
# Processing Record 38 of Set 4 | tateyama
# Processing Record 39 of Set 4 | abu samrah
# Processing Record 40 of Set 4 | olafsvik
# Processing Record 41 of Set 4 | tual
# Processing Record 42 of Set 4 | conneaut
# Processing Record 43 of Set 4 | urengoy
# Processing Record 44 of Set 4 | saskylakh
# Processing Record 45 of Set 4 | provideniya
# Processing Record 46 of Set 4 | gurgan
# City not found. Skipping...
# Processing Record 47 of Set 4 | ribeira grande
# Processing Record 48 of Set 4 | jhabua
# Processing Record 49 of Set 4 | kenai
# Processing Record 50 of Set 4 | lakes entrance
# Processing Record 1 of Set 5 | palma soriano
# Processing Record 2 of Set 5 | clyde river
# Processing Record 3 of Set 5 | vila franca do campo
# Processing Record 4 of Set 5 | mantua
# Processing Record 5 of Set 5 | yabelo
# Processing Record 6 of Set 5 | birao
# Processing Record 7 of Set 5 | sile
# Processing Record 8 of Set 5 | saint-leu
# Processing Record 9 of Set 5 | pandan
# Processing Record 10 of Set 5 | veraval
# Processing Record 11 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 12 of Set 5 | smirnykh
# Processing Record 13 of Set 5 | solnechnyy
# Processing Record 14 of Set 5 | owerri
# Processing Record 15 of Set 5 | kawana waters
# City not found. Skipping...
# Processing Record 16 of Set 5 | atar
# Processing Record 17 of Set 5 | bull savanna
# Processing Record 18 of Set 5 | afmadu
# City not found. Skipping...
# Processing Record 19 of Set 5 | saint-pierre
# Processing Record 20 of Set 5 | cabo san lucas
# Processing Record 21 of Set 5 | chokurdakh
# Processing Record 22 of Set 5 | ponta do sol
# Processing Record 23 of Set 5 | wasilla
# Processing Record 24 of Set 5 | upernavik
# Processing Record 25 of Set 5 | biak
# Processing Record 26 of Set 5 | northam
# Processing Record 27 of Set 5 | moerai
# Processing Record 28 of Set 5 | tessalit
# Processing Record 29 of Set 5 | nanortalik
# Processing Record 30 of Set 5 | namibe
# Processing Record 31 of Set 5 | arraial do cabo
# Processing Record 32 of Set 5 | wanning
# Processing Record 33 of Set 5 | kurbnesh
# Processing Record 34 of Set 5 | srednekolymsk
# Processing Record 35 of Set 5 | ontario
# Processing Record 36 of Set 5 | hithadhoo
# Processing Record 37 of Set 5 | grand gaube
# Processing Record 38 of Set 5 | williston
# Processing Record 39 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 5 | gat
# Processing Record 41 of Set 5 | sorland
# Processing Record 42 of Set 5 | sorgun
# Processing Record 43 of Set 5 | zhigalovo
# Processing Record 44 of Set 5 | mogadishu
# Processing Record 45 of Set 5 | san antonio
# Processing Record 46 of Set 5 | kembe
# Processing Record 47 of Set 5 | sao felix do xingu
# Processing Record 48 of Set 5 | kedougou
# Processing Record 49 of Set 5 | ileza
# Processing Record 50 of Set 5 | sorong
# Processing Record 1 of Set 6 | santa isabel do rio negro
# Processing Record 2 of Set 6 | lodi
# Processing Record 3 of Set 6 | ahipara
# Processing Record 4 of Set 6 | bridgton
# Processing Record 5 of Set 6 | luderitz
# Processing Record 6 of Set 6 | mahebourg
# Processing Record 7 of Set 6 | roebourne
# Processing Record 8 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 6 | aswan
# Processing Record 10 of Set 6 | karratha
# Processing Record 11 of Set 6 | lasa
# Processing Record 12 of Set 6 | nevelsk
# Processing Record 13 of Set 6 | asau
# Processing Record 14 of Set 6 | zhigansk
# Processing Record 15 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 16 of Set 6 | portobelo
# Processing Record 17 of Set 6 | floro
# Processing Record 18 of Set 6 | hofn
# Processing Record 19 of Set 6 | basqal
# Processing Record 20 of Set 6 | adilabad
# Processing Record 21 of Set 6 | svirsk
# Processing Record 22 of Set 6 | navrongo
# Processing Record 23 of Set 6 | meulaboh
# Processing Record 24 of Set 6 | sisimiut
# Processing Record 25 of Set 6 | nara
# Processing Record 26 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 6 | lompoc
# Processing Record 28 of Set 6 | dulce grande
# Processing Record 29 of Set 6 | shubarkuduk
# Processing Record 30 of Set 6 | pangody
# Processing Record 31 of Set 6 | ostersund
# Processing Record 32 of Set 6 | sindand
# City not found. Skipping...
# Processing Record 33 of Set 6 | eidsvag
# Processing Record 34 of Set 6 | la rioja
# Processing Record 35 of Set 6 | saint-georges
# Processing Record 36 of Set 6 | baykit
# Processing Record 37 of Set 6 | cosala
# Processing Record 38 of Set 6 | synya
# Processing Record 39 of Set 6 | marawi
# Processing Record 40 of Set 6 | tokzar
# City not found. Skipping...
# Processing Record 41 of Set 6 | sembe
# Processing Record 42 of Set 6 | arlit
# Processing Record 43 of Set 6 | tautira
# Processing Record 44 of Set 6 | mugur-aksy
# Processing Record 45 of Set 6 | tongliao
# Processing Record 46 of Set 6 | esperance
# Processing Record 47 of Set 6 | skjervoy
# Processing Record 48 of Set 6 | andapa
# Processing Record 49 of Set 6 | vanimo
# Processing Record 50 of Set 6 | avera
# Processing Record 1 of Set 7 | lata
# Processing Record 2 of Set 7 | tigil
# Processing Record 3 of Set 7 | makungu
# Processing Record 4 of Set 7 | boralday
# Processing Record 5 of Set 7 | san carlos
# Processing Record 6 of Set 7 | korla
# Processing Record 7 of Set 7 | pasighat
# Processing Record 8 of Set 7 | porto novo
# Processing Record 9 of Set 7 | katherine
# Processing Record 10 of Set 7 | iralaya
# Processing Record 11 of Set 7 | robe
# Processing Record 12 of Set 7 | iqaluit
# Processing Record 13 of Set 7 | miri
# Processing Record 14 of Set 7 | barcelona
# Processing Record 15 of Set 7 | susanville
# Processing Record 16 of Set 7 | burgos
# Processing Record 17 of Set 7 | mount isa
# Processing Record 18 of Set 7 | flagstaff
# Processing Record 19 of Set 7 | komsomolskiy
# Processing Record 20 of Set 7 | beringovskiy
# Processing Record 21 of Set 7 | tapes
# Processing Record 22 of Set 7 | japura
# Processing Record 23 of Set 7 | shestakovo
# Processing Record 24 of Set 7 | vage
# Processing Record 25 of Set 7 | viedma
# Processing Record 26 of Set 7 | walvis bay
# Processing Record 27 of Set 7 | darapidap
# Processing Record 28 of Set 7 | marsabit
# Processing Record 29 of Set 7 | conway
# Processing Record 30 of Set 7 | manzhouli
# Processing Record 31 of Set 7 | hambantota
# Processing Record 32 of Set 7 | severo-kurilsk
# Processing Record 33 of Set 7 | tsiroanomandidy
# Processing Record 34 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 7 | kailua
# Processing Record 37 of Set 7 | qunduz
# Processing Record 38 of Set 7 | aguilas
# Processing Record 39 of Set 7 | marienburg
# Processing Record 40 of Set 7 | banda aceh
# Processing Record 41 of Set 7 | pimentel
# Processing Record 42 of Set 7 | skibotn
# Processing Record 43 of Set 7 | brewster
# Processing Record 44 of Set 7 | codrington
# Processing Record 45 of Set 7 | iskateley
# Processing Record 46 of Set 7 | itoman
# Processing Record 47 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 7 | naze
# Processing Record 49 of Set 7 | tondano
# Processing Record 50 of Set 7 | sitka
# Processing Record 1 of Set 8 | labuhan
# Processing Record 2 of Set 8 | chulman
# Processing Record 3 of Set 8 | apollonia
# Processing Record 4 of Set 8 | tawang
# Processing Record 5 of Set 8 | chachapoyas
# Processing Record 6 of Set 8 | nan
# Processing Record 7 of Set 8 | boa viagem
# Processing Record 8 of Set 8 | sidney
# Processing Record 9 of Set 8 | sao gabriel da cachoeira
# Processing Record 10 of Set 8 | le passage
# Processing Record 11 of Set 8 | salalah
# Processing Record 12 of Set 8 | geraldton
# Processing Record 13 of Set 8 | te anau
# Processing Record 14 of Set 8 | zyryanka
# Processing Record 15 of Set 8 | riohacha
# Processing Record 16 of Set 8 | hoquiam
# Processing Record 17 of Set 8 | scarborough
# Processing Record 18 of Set 8 | elko
# Processing Record 19 of Set 8 | kaeo
# Processing Record 20 of Set 8 | port blair
# Processing Record 21 of Set 8 | portland
# Processing Record 22 of Set 8 | semirom
# Processing Record 23 of Set 8 | ylivieska
# Processing Record 24 of Set 8 | portgordon
# Processing Record 25 of Set 8 | pozhva
# Processing Record 26 of Set 8 | isla mujeres
# Processing Record 27 of Set 8 | varna
# Processing Record 28 of Set 8 | villa carlos paz
# Processing Record 29 of Set 8 | kununurra
# Processing Record 30 of Set 8 | tighina
# Processing Record 31 of Set 8 | tilichiki
# Processing Record 32 of Set 8 | casa grande
# Processing Record 33 of Set 8 | rush
# Processing Record 34 of Set 8 | egvekinot
# Processing Record 35 of Set 8 | gigmoto
# Processing Record 36 of Set 8 | saint-augustin
# Processing Record 37 of Set 8 | ambulu
# Processing Record 38 of Set 8 | katsuura
# Processing Record 39 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 8 | anamur
# Processing Record 41 of Set 8 | jaru
# Processing Record 42 of Set 8 | rawson
# Processing Record 43 of Set 8 | la ronge
# Processing Record 44 of Set 8 | nizhniy ingash
# Processing Record 45 of Set 8 | camacha
# Processing Record 46 of Set 8 | sisophon
# Processing Record 47 of Set 8 | khasan
# Processing Record 48 of Set 8 | gallup
# Processing Record 49 of Set 8 | andenes
# Processing Record 50 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 9 | padang
# Processing Record 3 of Set 9 | dongsheng
# Processing Record 4 of Set 9 | saldanha
# Processing Record 5 of Set 9 | sambalpur
# Processing Record 6 of Set 9 | christchurch
# Processing Record 7 of Set 9 | gamba
# Processing Record 8 of Set 9 | karasjok
# Processing Record 9 of Set 9 | jumla
# Processing Record 10 of Set 9 | xai-xai
# Processing Record 11 of Set 9 | qaqortoq
# Processing Record 12 of Set 9 | eureka
# Processing Record 13 of Set 9 | springdale
# Processing Record 14 of Set 9 | honjo
# Processing Record 15 of Set 9 | quimper
# Processing Record 16 of Set 9 | ekhabi
# Processing Record 17 of Set 9 | okandja
# City not found. Skipping...
# Processing Record 18 of Set 9 | muisne
# Processing Record 19 of Set 9 | kyshtovka
# Processing Record 20 of Set 9 | fare
# Processing Record 21 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 22 of Set 9 | cockburn town
# Processing Record 23 of Set 9 | lodja
# Processing Record 24 of Set 9 | lonato
# Processing Record 25 of Set 9 | taperoa
# Processing Record 26 of Set 9 | puri
# Processing Record 27 of Set 9 | orsk
# Processing Record 28 of Set 9 | bay city
# Processing Record 29 of Set 9 | goundi
# Processing Record 30 of Set 9 | talant
# Processing Record 31 of Set 9 | riyadh
# Processing Record 32 of Set 9 | amot
# Processing Record 33 of Set 9 | dakar
# Processing Record 34 of Set 9 | manokwari
# Processing Record 35 of Set 9 | cayenne
# Processing Record 36 of Set 9 | yumen
# Processing Record 37 of Set 9 | vilhena
# Processing Record 38 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 39 of Set 9 | gorin
# Processing Record 40 of Set 9 | kyra
# Processing Record 41 of Set 9 | telixtlahuaca
# City not found. Skipping...
# Processing Record 42 of Set 9 | goba
# Processing Record 43 of Set 9 | ojinaga
# Processing Record 44 of Set 9 | aden
# Processing Record 45 of Set 9 | mangan
# Processing Record 46 of Set 9 | pinawa
# Processing Record 47 of Set 9 | huarmey
# Processing Record 48 of Set 9 | nyaunglebin
# Processing Record 49 of Set 9 | longyearbyen
# Processing Record 50 of Set 9 | havoysund
# Processing Record 1 of Set 10 | siderno
# Processing Record 2 of Set 10 | goderich
# Processing Record 3 of Set 10 | thinadhoo
# Processing Record 4 of Set 10 | ternate
# Processing Record 5 of Set 10 | amuntai
# Processing Record 6 of Set 10 | boende
# Processing Record 7 of Set 10 | sabha
# Processing Record 8 of Set 10 | shitanjing
# Processing Record 9 of Set 10 | leningradskiy
# Processing Record 10 of Set 10 | le port
# Processing Record 11 of Set 10 | shingu
# Processing Record 12 of Set 10 | nicoya
# Processing Record 13 of Set 10 | linguere
# Processing Record 14 of Set 10 | swellendam
# Processing Record 15 of Set 10 | zhirnov
# Processing Record 16 of Set 10 | fuyang
# Processing Record 17 of Set 10 | urucara
# Processing Record 18 of Set 10 | touros
# Processing Record 19 of Set 10 | nishihara
# Processing Record 20 of Set 10 | lady frere
# Processing Record 21 of Set 10 | shush
# Processing Record 22 of Set 10 | mehamn
# Processing Record 23 of Set 10 | praia
# Processing Record 24 of Set 10 | bandarbeyla
# Processing Record 25 of Set 10 | fort nelson
# Processing Record 26 of Set 10 | hun
# Processing Record 27 of Set 10 | hualmay
# Processing Record 28 of Set 10 | qui nhon
# Processing Record 29 of Set 10 | malanje
# Processing Record 30 of Set 10 | hami
# Processing Record 31 of Set 10 | zeya
# Processing Record 32 of Set 10 | marigot
# Processing Record 33 of Set 10 | constitucion
# Processing Record 34 of Set 10 | yatou
# Processing Record 35 of Set 10 | san policarpo
# Processing Record 36 of Set 10 | san jose
# Processing Record 37 of Set 10 | araouane
# Processing Record 38 of Set 10 | san pedro buenavista
# Processing Record 39 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 40 of Set 10 | ornskoldsvik
# Processing Record 41 of Set 10 | kazerun
# Processing Record 42 of Set 10 | yambio
# Processing Record 43 of Set 10 | vestmannaeyjar
# Processing Record 44 of Set 10 | kloulklubed
# Processing Record 45 of Set 10 | apiai
# Processing Record 46 of Set 10 | lubango
# Processing Record 47 of Set 10 | pyay
# Processing Record 48 of Set 10 | zwedru
# Processing Record 49 of Set 10 | kralendijk
# Processing Record 50 of Set 10 | bodhan
# Processing Record 1 of Set 11 | nyurba
# Processing Record 2 of Set 11 | shahreza
# Processing Record 3 of Set 11 | baghdad
# Processing Record 4 of Set 11 | ahuimanu
# Processing Record 5 of Set 11 | kirakira
# Processing Record 6 of Set 11 | kapuskasing
# Processing Record 7 of Set 11 | galbshtadt
# Processing Record 8 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 9 of Set 11 | kanniyakumari
# Processing Record 10 of Set 11 | nalut
# Processing Record 11 of Set 11 | ketchikan
# Processing Record 12 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 13 of Set 11 | chapeco
# Processing Record 14 of Set 11 | takoradi
# Processing Record 15 of Set 11 | nokaneng
# Processing Record 16 of Set 11 | burica
# City not found. Skipping...
# Processing Record 17 of Set 11 | orcopampa
# Processing Record 18 of Set 11 | shakawe
# Processing Record 19 of Set 11 | balas
# Processing Record 20 of Set 11 | sabang
# Processing Record 21 of Set 11 | sfantu gheorghe
# Processing Record 22 of Set 11 | coruripe
# Processing Record 23 of Set 11 | puerto escondido
# Processing Record 24 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 25 of Set 11 | ilinskiy
# Processing Record 26 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 27 of Set 11 | nkoteng
# Processing Record 28 of Set 11 | luau
# Processing Record 29 of Set 11 | francisco beltrao
# Processing Record 30 of Set 11 | grindavik
# Processing Record 31 of Set 11 | keetmanshoop
# Processing Record 32 of Set 11 | xinyu
# Processing Record 33 of Set 11 | tanout
# Processing Record 34 of Set 11 | jizan
# Processing Record 35 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 11 | puerto del rosario
# Processing Record 37 of Set 11 | den helder
# Processing Record 38 of Set 11 | faya
# Processing Record 39 of Set 11 | poronaysk
# Processing Record 40 of Set 11 | gambo
# Processing Record 41 of Set 11 | balkanabat
# Processing Record 42 of Set 11 | eydhafushi
# Processing Record 43 of Set 11 | san luis
# Processing Record 44 of Set 11 | cidreira
# Processing Record 45 of Set 11 | bafia
# Processing Record 46 of Set 11 | campo formoso
# Processing Record 47 of Set 11 | chiredzi
# Processing Record 48 of Set 11 | gulshat
# City not found. Skipping...
# Processing Record 49 of Set 11 | dubovka
# Processing Record 50 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 12 | half moon bay
# Processing Record 2 of Set 12 | kuldur
# Processing Record 3 of Set 12 | laguna
# Processing Record 4 of Set 12 | sal rei
# Processing Record 5 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 6 of Set 12 | cordoba
# Processing Record 7 of Set 12 | peachland
# Processing Record 8 of Set 12 | lodwar
# Processing Record 9 of Set 12 | dzaoudzi
# Processing Record 10 of Set 12 | maragogi
# Processing Record 11 of Set 12 | bushehr
# Processing Record 12 of Set 12 | adet
# Processing Record 13 of Set 12 | bridlington
# Processing Record 14 of Set 12 | kropotkin
# Processing Record 15 of Set 12 | lakatoro
# Processing Record 16 of Set 12 | loei
# Processing Record 17 of Set 12 | noumea
# Processing Record 18 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 19 of Set 12 | voroshnevo
# Processing Record 20 of Set 12 | vestmanna
# Processing Record 21 of Set 12 | vardo
# Processing Record 22 of Set 12 | upata
# Processing Record 23 of Set 12 | ko samui
# Processing Record 24 of Set 12 | lugovskoy
# Processing Record 25 of Set 12 | flinders
# Processing Record 26 of Set 12 | iguape
# Processing Record 27 of Set 12 | letlhakeng
# Processing Record 28 of Set 12 | taltal
# Processing Record 29 of Set 12 | inhuma
# Processing Record 30 of Set 12 | paamiut
# Processing Record 31 of Set 12 | waingapu
# Processing Record 32 of Set 12 | seddon
# Processing Record 33 of Set 12 | kushima
# Processing Record 34 of Set 12 | moose factory
# Processing Record 35 of Set 12 | saldana
# Processing Record 36 of Set 12 | tecpatan
# Processing Record 37 of Set 12 | camacupa
# Processing Record 38 of Set 12 | broken hill
# Processing Record 39 of Set 12 | la asuncion
# Processing Record 40 of Set 12 | evensk
# Processing Record 41 of Set 12 | neerijnen
# Processing Record 42 of Set 12 | bilma
# Processing Record 43 of Set 12 | ribas do rio pardo
# Processing Record 44 of Set 12 | nador
# Processing Record 45 of Set 12 | maniitsoq
# Processing Record 46 of Set 12 | uyuni
# Processing Record 47 of Set 12 | erzin
# Processing Record 48 of Set 12 | tezu
# Processing Record 49 of Set 12 | adwa
# Processing Record 50 of Set 12 | arman
# Processing Record 1 of Set 13 | hobyo
# Processing Record 2 of Set 13 | ulladulla
# Processing Record 3 of Set 13 | bongandanga
# Processing Record 4 of Set 13 | milyutinskaya
# Processing Record 5 of Set 13 | kruisfontein
# Processing Record 6 of Set 13 | manaure
# Processing Record 7 of Set 13 | batesville
# Processing Record 8 of Set 13 | awjilah
# Processing Record 9 of Set 13 | batagay
# Processing Record 10 of Set 13 | beipiao
# Processing Record 11 of Set 13 | muttupet
# Processing Record 12 of Set 13 | djambala
# Processing Record 13 of Set 13 | kytlym
# City not found. Skipping...
# Processing Record 14 of Set 13 | de aar
# Processing Record 15 of Set 13 | el faiyum
# City not found. Skipping...
# Processing Record 16 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 17 of Set 13 | menongue
# Processing Record 18 of Set 13 | miechow
# Processing Record 19 of Set 13 | ambilobe
# Processing Record 20 of Set 13 | tres arroyos
# Processing Record 21 of Set 13 | krasnoselkup
# Processing Record 22 of Set 13 | edd
# Processing Record 23 of Set 13 | nanzhou
# Processing Record 24 of Set 13 | san ignacio
# Processing Record 25 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 26 of Set 13 | jibuti
# Processing Record 27 of Set 13 | chimbote
# Processing Record 28 of Set 13 | ewa beach
# Processing Record 29 of Set 13 | kasongo-lunda
# Processing Record 30 of Set 13 | umkomaas
# Processing Record 31 of Set 13 | ahvaz
# Processing Record 32 of Set 13 | harper
# Processing Record 33 of Set 13 | darab
# Processing Record 34 of Set 13 | satana
# Processing Record 35 of Set 13 | altamont
# Processing Record 36 of Set 13 | mount gambier
# Processing Record 37 of Set 13 | nuevo progreso
# Processing Record 38 of Set 13 | chengde
# Processing Record 39 of Set 13 | lusambo
# Processing Record 40 of Set 13 | perth
# Processing Record 41 of Set 13 | sao joao da barra
# Processing Record 42 of Set 13 | westport
# Processing Record 43 of Set 13 | aksarka
# Processing Record 44 of Set 13 | brownsville
# Processing Record 45 of Set 13 | chepareria
# Processing Record 46 of Set 13 | lumsden
# Processing Record 47 of Set 13 | pamplona
# Processing Record 48 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 49 of Set 13 | alofi
# Processing Record 50 of Set 13 | kieta
# Processing Record 1 of Set 14 | lima
# Processing Record 2 of Set 14 | kyzyl-suu
# Processing Record 3 of Set 14 | yenangyaung
# Processing Record 4 of Set 14 | shirokiy
# Processing Record 5 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 6 of Set 14 | bideford
# Processing Record 7 of Set 14 | chengmai
# City not found. Skipping...
# Processing Record 8 of Set 14 | haradok
# Processing Record 9 of Set 14 | fairbanks
# Processing Record 10 of Set 14 | joshimath
# Processing Record 11 of Set 14 | bonthe
# Processing Record 12 of Set 14 | deputatskiy
# Processing Record 13 of Set 14 | muroto
# Processing Record 14 of Set 14 | breyten
# Processing Record 15 of Set 14 | sungaipenuh
# Processing Record 16 of Set 14 | bratsk
# Processing Record 17 of Set 14 | pueblo nuevo
# Processing Record 18 of Set 14 | kargil
# Processing Record 19 of Set 14 | duluth
# Processing Record 20 of Set 14 | brae
# Processing Record 21 of Set 14 | san pedro
# Processing Record 22 of Set 14 | hirara
# Processing Record 23 of Set 14 | yizheng
# Processing Record 24 of Set 14 | dhadar
# Processing Record 25 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 26 of Set 14 | macau
# Processing Record 27 of Set 14 | chiavari
# Processing Record 28 of Set 14 | price
# Processing Record 29 of Set 14 | marsh harbour
# Processing Record 30 of Set 14 | santa cruz
# Processing Record 31 of Set 14 | bansi
# Processing Record 32 of Set 14 | padilla
# Processing Record 33 of Set 14 | lipin bor
# Processing Record 34 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 35 of Set 14 | randolph
# Processing Record 36 of Set 14 | bilibino
# Processing Record 37 of Set 14 | pangnirtung
# Processing Record 38 of Set 14 | upington
# Processing Record 39 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 40 of Set 14 | caravelas
# Processing Record 41 of Set 14 | bembereke
# Processing Record 42 of Set 14 | yenagoa
# Processing Record 43 of Set 14 | matamoros
# Processing Record 44 of Set 14 | ilhabela
# Processing Record 45 of Set 14 | snezhnogorsk
# Processing Record 46 of Set 14 | valparaiso
# Processing Record 47 of Set 14 | bowen
# Processing Record 48 of Set 14 | impfondo
# Processing Record 49 of Set 14 | victor harbor
# Processing Record 50 of Set 14 | nhulunbuy
# Processing Record 1 of Set 15 | dumbravita
# Processing Record 2 of Set 15 | manta
# Processing Record 3 of Set 15 | haines junction
# Processing Record 4 of Set 15 | taoudenni
# Processing Record 5 of Set 15 | aviles
# Processing Record 6 of Set 15 | atambua
# Processing Record 7 of Set 15 | jinchang
# Processing Record 8 of Set 15 | praya
# Processing Record 9 of Set 15 | nioki
# Processing Record 10 of Set 15 | manacapuru
# Processing Record 11 of Set 15 | ginir
# Processing Record 12 of Set 15 | turukhansk
# Processing Record 13 of Set 15 | venado tuerto
# Processing Record 14 of Set 15 | dingzhou
# Processing Record 15 of Set 15 | urumqi
# Processing Record 16 of Set 15 | buala
# Processing Record 17 of Set 15 | los llanos de aridane
# Processing Record 18 of Set 15 | raudeberg
# Processing Record 19 of Set 15 | quirinopolis
# Processing Record 20 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 21 of Set 15 | astoria
# Processing Record 22 of Set 15 | nayoro
# Processing Record 23 of Set 15 | mlonggo
# Processing Record 24 of Set 15 | meru
# Processing Record 25 of Set 15 | twin falls
# Processing Record 26 of Set 15 | wanaka
# Processing Record 27 of Set 15 | luoyang
# Processing Record 28 of Set 15 | zhanaozen
# Processing Record 29 of Set 15 | baoning
# Processing Record 30 of Set 15 | mitchell
# Processing Record 31 of Set 15 | port macquarie
# Processing Record 32 of Set 15 | honiara
# Processing Record 33 of Set 15 | point pleasant
# Processing Record 34 of Set 15 | mitu
# Processing Record 35 of Set 15 | ambajogai
# Processing Record 36 of Set 15 | belyy yar
# Processing Record 37 of Set 15 | smithers
# Processing Record 38 of Set 15 | balakhninskiy
# Processing Record 39 of Set 15 | wuning
# Processing Record 40 of Set 15 | marzuq
# Processing Record 41 of Set 15 | waddan
# Processing Record 42 of Set 15 | jacareacanga
# Processing Record 43 of Set 15 | marsa matruh
# Processing Record 44 of Set 15 | necochea
# Processing Record 45 of Set 15 | colares
# Processing Record 46 of Set 15 | aljustrel
# Processing Record 47 of Set 15 | mindelo
# Processing Record 48 of Set 15 | basoko
# Processing Record 49 of Set 15 | kuching
# Processing Record 50 of Set 15 | konstantinovka
# Processing Record 1 of Set 16 | medea
# Processing Record 2 of Set 16 | trelew
# Processing Record 3 of Set 16 | atagay
# Processing Record 4 of Set 16 | marystown
# Processing Record 5 of Set 16 | virginia beach
# Processing Record 6 of Set 16 | birjand
# Processing Record 7 of Set 16 | victoria point
# Processing Record 8 of Set 16 | kiruna
# Processing Record 9 of Set 16 | ginda
# Processing Record 10 of Set 16 | henties bay
# Processing Record 11 of Set 16 | syracuse
# -----------------------
# Data Retrieval Complete

# %%
len(city_data)
# Out:
# 700

# %%
# Add city data to a new dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Bethel  41.3712  -73.4140     73.63        57          19
# 1           Pingxiang  27.6167  113.8500     68.65        78          61
# 2        Punta Arenas -53.1500  -70.9167     41.11        93         100
# 3  La Baule-Escoublac  47.2922   -2.3640     64.71        92          75
# 4           Barinitas   8.7622  -70.4111     72.88        87          95
#
#    Wind Speed Country Current Description
# 0        4.70      US          few clouds
# 1        1.10      CN       broken clouds
# 2       13.58      CL     overcast clouds
# 3        8.05      FR       broken clouds
# 4        2.30      VE     overcast clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
#output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
#city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [11], in <cell line: 6>()
#       3 output_data_file = "Weather_Database/WeatherPy_Database.csv"
#       5 # Export the City_Data into a CSV.
# ----> 6 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
#    3555     encoding=encoding,
#    3556     errors=errors,
#    3557     compression=compression,
#    3558     quoting=quoting,
#    3559     columns=columns,
#    3560     index_label=index_label,
#    3561     mode=mode,
#    3562     chunksize=chunksize,
#    3563     quotechar=quotechar,
#    3564     date_format=date_format,
#    3565     doublequote=doublequote,
#    3566     escapechar=escapechar,
#    3567     storage_options=storage_options,
#    3568 )
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/format.py:1180, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1159     created_buffer = False
#    1161 csv_formatter = CSVFormatter(
#    1162     path_or_buf=path_or_buf,
#    1163     line_terminator=line_terminator,
#    (...)
#    1178     formatter=self.fmt,
#    1179 )
# -> 1180 csv_formatter.save()
#    1182 if created_buffer:
#    1183     assert isinstance(path_or_buf, StringIO)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.line_terminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py:697, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     695 # Only for write methods
#     696 if "r" not in mode and is_path:
# --> 697     check_parent_directory(str(handle))
#     699 if compression:
#     700     if compression != "zstd":
#     701         # compression libraries do not like an explicit text-mode
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py:571, in check_parent_directory(path)
#     569 parent = Path(path).parent
#     570 if not parent.is_dir():
# --> 571     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'Weather_Database'
